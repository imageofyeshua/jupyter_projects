# %%
def myfunction():
    print('Hello Daniel')

# %%
myfunction()
# Out:
# Hello Daniel

# %%
int(3.2)
# Out:
# 3

# %%
def hisfunction(name):
    print('Hello %s.' %name)

# %%
hisfunction('Daniel')
# Out:
# Hello Daniel.

# %%
a = int(input('input a number: '))
# Out:
# input a number:  34234

# %%
type(a)
# Out:
# int

# %%
def divisionWithInput():
    x = int(input('Input the numerator:'))
    y = int(input('Input tne denominator:'))

    divis = int(x/y)
    remainder = x%y

    print('%g goes into %g, %g times with a remainder of %g' %(y,x,divis,remainder))

# %%
divisionWithInput()
# Out:
# Input the numerator: 12
# Input tne denominator: 5
# 5 goes into 12, 2 times with a remainder of 2

# %%
sum??
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.
# Type:      builtin_function_or_method

# %%
aList = [1,2,3,4]
sum(aList,-3)
# Out:
# 7

# %%
import numpy as np
import inspect

# %%
# inspect.getsourcelines(np.linspace) # get source code for a function

# %%
def myfactorial(val):
    return np.prod(np.arange(1,val+1))

# %%
myfactorial(5)
# Out:
# np.int64(120)

# %%
np.prod([1,2,3,4])
# Out:
# np.int64(24)

# %%
import math

k = 23 
print(math.factorial(k), myfactorial(k))
# Out:
# 25852016738884976640000 8128291617894825984

# %%
math.factorial??
# Out:
# Signature: math.factorial(n, /)
# Docstring:
# Find n!.
#
# Raise a ValueError if x is negative or non-integral.
# Type:      builtin_function_or_method

# %%
def coinflip(N):
    pCoinFlips = np.mean(np.random.randn(N)>0)
    print(str(N) + ' coin flips had ' + str(100*pCoinFlips) + '% heads.')

# %%
coinflip(1000)
# Out:
# 1000 coin flips had 51.5% heads.
