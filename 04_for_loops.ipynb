# %%
for i in [0,1,2,3]:
    print(i*2)
# Out:
# 0
# 2
# 4
# 6

# %%
list(range(0,3))
# Out:
# [0, 1, 2]

# %%
for index in range(0,5):
    print('This is the %gth iteration.' %index)
# Out:
# This is the 0th iteration.
# This is the 1th iteration.
# This is the 2th iteration.
# This is the 3th iteration.
# This is the 4th iteration.

# %%
for t in range(0,7):
    num = t**2
    print(num)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36

# %%
base = 30
for num in range(0,10):
    print('%g to the power of %g is %g' %(base,num,base**num))
# Out:
# 30 to the power of 0 is 1
# 30 to the power of 1 is 30
# 30 to the power of 2 is 900
# 30 to the power of 3 is 27000
# 30 to the power of 4 is 810000
# 30 to the power of 5 is 2.43e+07
# 30 to the power of 6 is 7.29e+08
# 30 to the power of 7 is 2.187e+10
# 30 to the power of 8 is 6.561e+11
# 30 to the power of 9 is 1.9683e+13
