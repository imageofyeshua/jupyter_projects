# %%
s1 = '4'
s2 = '4.7'
n1 = 5
n2 = 5.8

print( type(int(s1)) )
# print( int(s1) )

print( float(s1) )
print( float(s2) )
print( int(float(s2)) )

str(n2)*2
# Out:
# <class 'int'>
# 4.0
# 4.7
# 4
# '5.85.8'
