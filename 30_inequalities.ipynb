# %%
import sympy as sym
from IPython.display import display,Math

# %%
x = sym.symbols('x')

expr = (x-1)*(x+3) > 0 

display(sym.solve(expr))
display(Math(sym.latex(sym.solve(expr))))
# Out:
# ((-oo < x) & (x < -3)) | ((1 < x) & (x < oo))
# $\displaystyle \left(-\infty < x \wedge x < -3\right) \vee \left(1 < x \wedge x < \infty\right)$

# %%
sym.oo > 2342343243243
# Out:
# True

# %%
a,b,c = sym.symbols('a,c,b')

ex = a*x > b**2/c
display(Math(sym.latex(ex)))
sym.solve(ex,x)
# Out:
# $\displaystyle a x > \frac{c^{2}}{b}$
# a*x > c**2/b

# %%
func = 3*x/2 + (4-5*x)/3 <= 2 - (5*(2-x))/4

display(Math(sym.latex(func)))
sym.solve(func)
# Out:
# $\displaystyle \frac{4}{3} - \frac{x}{6} \leq \frac{5 x}{4} - \frac{1}{2}$
# (22/17 <= x) & (x < oo)
