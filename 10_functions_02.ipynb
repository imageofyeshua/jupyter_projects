# %%
from IPython.display import display,Math

def powers(x, y):
    display(Math('{%g}^{%g}=%g' %(x,y,x**y)))

def division(x, y):
    display(Math('\\frac{%g}{%g}=%g' %(x,y,x/y)))

# %%
def calculate():
    x = int(input('input X:'))
    y = int(input('input Y:'))
    
    display(Math('\\text{Press "1" to compute }{%g}^{%g}\\text{ or "2" to compute }\\frac{%g}{%g}' %(x,y,x,y)))

    selection = input('Your choice:')

    if selection == '1':
        powers(x,y)
    elif selection == '2':
        division(x,y)
    else:
        print('Invalid selection!')

# %%
calculate()
# Out:
# input X: 2
# input Y: 4
# $\displaystyle \text{Press "1" to compute }{2}^{4}\text{ or "2" to compute }\frac{2}{4}$
# Your choice: 1
# $\displaystyle {2}^{4}=16$

# %%
calculate()
# Out:
# input X: 12
# input Y: 46
# $\displaystyle \text{Press "1" to compute }{12}^{46}\text{ or "2" to compute }\frac{12}{46}$
# Your choice: 2
# $\displaystyle \frac{12}{46}=0.26087$
