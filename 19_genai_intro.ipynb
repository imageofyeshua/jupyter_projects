# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="What will be the kingdom of God like in Millenium?",
    config=types.GenerateContentConfig(
        max_output_tokens=100,
    ),
)

print(response.text)
# Out:
#  physical/spiritual earthly

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text=' physical/spiritual earthly',
#             thought_signature=b"\x12\x81\x04\n\xfe\x03\x01\x11M2\x0f5\x19\x1e\xdcM\xad\xb8\xbd\xd1\x97\xd7\xf9\xb9\xbdz\x03^'\xf9#\xee\xcbf\xa8\xae\xa0\x8bQ\x07x\x07{\xe4K\xd8\xe8\x92:&\xad\xef\xfc8\xc0k?a\xefF\xc2a\x8e\xdd\x8e\xb8\xb8\xf1a\x89['V\xf8\x01\xb8i_~\xc5\xdf\x18\xd8\x7fh\x90\x06\xdb:]\xa9\x16s-\xe0\xa5~...'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.MAX_TOKENS: 'MAX_TOKENS'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3.6-flash',
#   response_id='bL-DarqKDYin2roPv-WL4AI',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=12>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=4,
#     prompt_token_count=15,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=15
#       ),
#     ],
#     thoughts_token_count=92,
#     total_token_count=111
#   )
# )
