# %% [markdown]
# #

# %%
import sympy as sym
from IPython.display import display,Math

# %%
# f-strings

svar = 'Daniel'
nvar = 7

print(f'Hi my name is {svar} and I eat {nvar} words every day!!')
# Out:
# Hi my name is Daniel and I eat 7 words every day!!

# %%
x,y = sym.symbols('x,y')
expr = 3/x
# display(Math(f'\\frac{{{sym.latex(expr)}}}{{y}}'))
display(Math('\\frac{%s}{%s}'%(sym.latex(expr),y)))
display(Math('\\frac{%s}{%s}'%(sym.latex(expr),y)))
# Out:
# $\displaystyle \frac{\frac{3}{x}}{y}$
# $\displaystyle \frac{\frac{3}{x}}{y}$

# %%
Math('\\frac{%s}{%s}'%(sym.latex(expr),y))
# Out:
# $\displaystyle \frac{\frac{3}{x}}{y}$
